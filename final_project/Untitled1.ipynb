# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from astropy.io import fits
from astropy.table import Table

# %%
ra = np.array([144.048, 150.954, 157.858])
dec = np.array([9.194, 12.193, 15.097])

plt.figure()
plt.scatter(ra, dec)
plt.show()

# %%
df = pd.read_csv('data_project - Sheet1.csv')
df
# Out:
#     MDL         X         Y  Distance  SNR  FWHM  Deflection  DeflectionError
# 0     1   120.905   330.576     4.566  162  1.90       0.450            0.063
# 1     2   425.492  1120.897     3.000   35  1.77       0.538           -0.051
# 2     3   788.888   646.437     3.058   19  1.67       0.585            0.007
# 3     4   527.111    17.981     4.522  165  1.71       0.329           -0.062
# 4     5  3051.848    78.155     4.817   52  1.72       0.369            0.002
# 5     6   841.929   213.205     3.802  138  1.60       0.547            0.083
# 6     7  2815.052   510.911     3.760   19  1.60       0.406           -0.064
# 7     8   602.019   746.530     3.168   73  1.77       0.584            0.026
# 8     9   651.884   313.647     3.828   51  1.76       0.354           -0.107
# 9    10  2014.265   112.192     3.694  139  1.59       0.537            0.059
# 10   11   828.821   299.299     3.649   21  1.64       0.507            0.023
# ...

# %%
x = df['X']
y = df['Y']

plt.figure()
plt.scatter(x, y)
plt.show()

# %%
distance = df['Distance']
deflection = df['Deflection']

plt.figure()
plt.scatter(distance, deflection)
plt.show()

# %%
df = pd.read_csv('https://cdn.gea.esac.esa.int/Gaia/gdr1/gaia_source/fits/GaiaSource_000-000-000.fits')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_csv('https://cdn.gea.esac.esa.int/Gaia/gdr1/gaia_source/fits/GaiaSource_000-000-000.fits')
#       2 df
#
# ...
