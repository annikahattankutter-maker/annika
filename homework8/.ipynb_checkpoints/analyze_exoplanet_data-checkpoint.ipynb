# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('exoplanet_data.csv', on_bad_lines='skip',comment = '#')
df
# Out:
#          pl_name   hostname  default_flag  sy_snum  sy_pnum  discoverymethod  \
# 0        7 CMa c      7 CMa             1        1        2  Radial Velocity
# 1        7 CMa c      7 CMa             0        1        2  Radial Velocity
# 2       DMPP-1 b     DMPP-1             1        1        4  Radial Velocity
# 3       DMPP-1 c     DMPP-1             1        1        4  Radial Velocity
# 4       DMPP-1 d     DMPP-1             1        1        4  Radial Velocity
# ..           ...        ...           ...      ...      ...              ...
# 562    bet Pic c    bet Pic             1        1        2  Radial Velocity
# 563    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 564    bet Pic c    bet Pic             0        1        2  Radial Velocity
# 565  eps Ind A b  eps Ind A             0        3        1  Radial Velocity
# 566  eps Ind A b  eps Ind A             1        3        1  Radial Velocity
#
#      disc_year           disc_facility              soltype  pl_controv_flag  \
# 0         2019  Multiple Observatories  Published Confirmed                0
# 1         2019  Multiple Observatories  Published Confirmed                0
# 2         2019    La Silla Observatory  Published Confirmed                0
# 3         2019    La Silla Observatory  Published Confirmed                0
# 4         2019    La Silla Observatory  Published Confirmed                0
# ..         ...                     ...                  ...              ...
# 562       2019    La Silla Observatory  Published Confirmed                0
# 563       2019    La Silla Observatory  Published Confirmed                0
# 564       2019    La Silla Observatory  Published Confirmed                0
# 565       2019    La Silla Observatory  Published Confirmed                0
# 566       2019    La Silla Observatory  Published Confirmed                0
#
#      ... sy_vmagerr2  sy_kmag  sy_kmagerr1  sy_kmagerr2  sy_gaiamag  \
# 0    ...       -0.03    1.564        0.252       -0.252     3.67853
# 1    ...       -0.03    1.564        0.252       -0.252     3.67853
# 2    ...       -0.03    6.690        0.024       -0.024     7.85032
# 3    ...       -0.03    6.690        0.024       -0.024     7.85032
# 4    ...       -0.03    6.690        0.024       -0.024     7.85032
# ..   ...         ...      ...          ...          ...         ...
# 562  ...       -0.03    3.526        0.222       -0.222     3.82015
# 563  ...       -0.03    3.526        0.222       -0.222     3.82015
# 564  ...       -0.03    3.526        0.222       -0.222     3.82015
# 565  ...       -0.03    2.237        0.240       -0.240     4.34562
# 566  ...       -0.03    2.237        0.240       -0.240     4.34562
#
#      sy_gaiamagerr1  sy_gaiamagerr2   rowupdate  pl_pubdate  releasedate
# 0          0.004135       -0.004135  2019-10-18     2019-11   2019-10-24
# 1          0.004135       -0.004135  2024-09-13     2024-07   2024-09-13
# 2          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# 3          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# 4          0.000290       -0.000290  2020-01-23     2019-12   2020-01-30
# ..              ...             ...         ...         ...          ...
# 562        0.004427       -0.004427  2023-06-12     2022-09   2023-06-12
# 563        0.004427       -0.004427  2025-09-25     2020-10   2025-09-25
# 564        0.004427       -0.004427  2019-08-23     2019-08   2019-08-29
# 565        0.007374       -0.007374  2019-10-18     2019-12   2019-10-24
# 566        0.007374       -0.007374  2024-08-07     2024-09   2024-08-07
#
# [567 rows x 92 columns]

# %%
df.shape
# Out:
# (567, 92)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 92 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          567 non-null    object
#  1   hostname         567 non-null    object
#  2   default_flag     567 non-null    int64
#  3   sy_snum          567 non-null    int64
#  4   sy_pnum          567 non-null    int64
#  5   discoverymethod  567 non-null    object
#  6   disc_year        567 non-null    int64
#  7   disc_facility    567 non-null    object
#  8   soltype          567 non-null    object
#  9   pl_controv_flag  567 non-null    int64
#  10  pl_refname       567 non-null    object
#  11  pl_orbper        493 non-null    float64
#  12  pl_orbpererr1    480 non-null    float64
#  13  pl_orbpererr2    480 non-null    float64
#  14  pl_orbperlim     493 non-null    float64
#  15  pl_orbsmax       309 non-null    float64
#  16  pl_orbsmaxerr1   288 non-null    float64
#  17  pl_orbsmaxerr2   288 non-null    float64
#  18  pl_orbsmaxlim    317 non-null    float64
#  19  pl_rade          290 non-null    float64
#  20  pl_radeerr1      287 non-null    float64
#  21  pl_radeerr2      287 non-null    float64
#  22  pl_radelim       293 non-null    float64
#  23  pl_radj          290 non-null    float64
#  24  pl_radjerr1      287 non-null    float64
#  25  pl_radjerr2      287 non-null    float64
#  26  pl_radjlim       290 non-null    float64
#  27  pl_bmasse        287 non-null    float64
#  28  pl_bmasseerr1    277 non-null    float64
#  29  pl_bmasseerr2    277 non-null    float64
#  30  pl_bmasselim     287 non-null    float64
#  31  pl_bmassj        287 non-null    float64
#  32  pl_bmassjerr1    277 non-null    float64
#  33  pl_bmassjerr2    277 non-null    float64
#  34  pl_bmassjlim     287 non-null    float64
#  35  pl_bmassprov     287 non-null    object
#  36  pl_orbeccen      262 non-null    float64
#  37  pl_orbeccenerr1  165 non-null    float64
#  38  pl_orbeccenerr2  165 non-null    float64
#  39  pl_orbeccenlim   265 non-null    float64
#  40  pl_insol         148 non-null    float64
#  41  pl_insolerr1     75 non-null     float64
#  42  pl_insolerr2     75 non-null     float64
#  43  pl_insollim      154 non-null    float64
#  44  pl_eqt           236 non-null    float64
#  45  pl_eqterr1       138 non-null    float64
#  46  pl_eqterr2       138 non-null    float64
#  47  pl_eqtlim        239 non-null    float64
#  48  ttv_flag         567 non-null    int64
#  49  st_refname       540 non-null    object
#  50  st_spectype      195 non-null    object
#  51  st_teff          408 non-null    float64
#  52  st_tefferr1      400 non-null    float64
#  53  st_tefferr2      400 non-null    float64
#  54  st_tefflim       408 non-null    float64
#  55  st_rad           399 non-null    float64
#  56  st_raderr1       382 non-null    float64
#  57  st_raderr2       382 non-null    float64
#  58  st_radlim        399 non-null    float64
#  59  st_mass          427 non-null    float64
#  60  st_masserr1      395 non-null    float64
#  61  st_masserr2      395 non-null    float64
#  62  st_masslim       427 non-null    float64
#  63  st_met           275 non-null    float64
#  64  st_meterr1       273 non-null    float64
#  65  st_meterr2       273 non-null    float64
#  66  st_metlim        278 non-null    float64
#  67  st_metratio      274 non-null    object
#  68  st_logg          352 non-null    float64
#  69  st_loggerr1      336 non-null    float64
#  70  st_loggerr2      336 non-null    float64
#  71  st_logglim       352 non-null    float64
#  72  sy_refname       567 non-null    object
#  73  rastr            567 non-null    object
#  74  ra               567 non-null    float64
#  75  decstr           567 non-null    object
#  76  dec              567 non-null    float64
#  77  sy_dist          561 non-null    float64
#  78  sy_disterr1      555 non-null    float64
#  79  sy_disterr2      555 non-null    float64
#  80  sy_vmag          521 non-null    float64
#  81  sy_vmagerr1      521 non-null    float64
#  82  sy_vmagerr2      521 non-null    float64
#  83  sy_kmag          516 non-null    float64
#  84  sy_kmagerr1      510 non-null    float64
#  85  sy_kmagerr2      510 non-null    float64
#  86  sy_gaiamag       500 non-null    float64
#  87  sy_gaiamagerr1   500 non-null    float64
#  88  sy_gaiamagerr2   500 non-null    float64
#  89  rowupdate        567 non-null    object
#  90  pl_pubdate       567 non-null    object
#  91  releasedate      567 non-null    object
# dtypes: float64(70), int64(6), object(16)
# memory usage: 407.7+ KB

# %%
# I dont know columns = rastr, sy_vmag, ttv_flagg, st_metratio, and decstr

# %%
# 1) pl_name = planet name
#    planet name most commonly used in literature
# 2) hostname = host name
#    stellar name most commonly used in literature
# 3) discoverymethod = discovery method
#    method by which the planet was first identified
# 4) st_spectype = spectral type
#    classification of the star based on their spectral characteristics following
#    the Morgan-Keenan system
# 5) pl_eqt = equilibrium temperature [K]
#    equilibrium temperature of the planet as modeled by a black body heated only
#    by its host star
# 6) pl_bmassj = planet mass or mass*sin(i) [Jupiter mass]
#    best planet mass estimate available, in order of preference

# %%
df_small = df[['pl_name', 'hostname', 'discoverymethod', 'st_spectype', 'pl_eqt', 'pl_bmassj']]
df_small = df_small.dropna()
df_small
# Out:
#          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 2       DMPP-1 b     DMPP-1  Radial Velocity        F8 V   877.0   0.076362
# 3       DMPP-1 c     DMPP-1  Radial Velocity        F8 V  1239.0   0.030205
# 4       DMPP-1 d     DMPP-1  Radial Velocity        F8 V  1632.0   0.010540
# 5       DMPP-1 e     DMPP-1  Radial Velocity        F8 V  1314.0   0.012994
# 6       DMPP-2 b     DMPP-2  Radial Velocity        F5 V  1000.0   0.437000
# ..           ...        ...              ...         ...     ...        ...
# 546   WASP-185 b   WASP-185          Transit        G0 V  1160.0   0.980000
# 549   WASP-190 b   WASP-190          Transit     F6 IV-V  1500.0   1.000000
# 555   WASP-192 b   WASP-192          Transit        G0 V  1620.0   2.300000
# 561       XO-7 b       XO-7          Transit        G0 V  1743.0   0.709000
# 566  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0   6.310000
#
# [67 rows x 6 columns]

# %%
df_small.shape
# Out:
# (67, 6)

# %%
df_small.head(5)
# Out:
#     pl_name hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 2  DMPP-1 b   DMPP-1  Radial Velocity        F8 V   877.0   0.076362
# 3  DMPP-1 c   DMPP-1  Radial Velocity        F8 V  1239.0   0.030205
# 4  DMPP-1 d   DMPP-1  Radial Velocity        F8 V  1632.0   0.010540
# 5  DMPP-1 e   DMPP-1  Radial Velocity        F8 V  1314.0   0.012994
# 6  DMPP-2 b   DMPP-2  Radial Velocity        F5 V  1000.0   0.437000

# %%
df_small.tail(5)
# Out:
#          pl_name   hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj
# 546   WASP-185 b   WASP-185          Transit        G0 V  1160.0      0.980
# 549   WASP-190 b   WASP-190          Transit     F6 IV-V  1500.0      1.000
# 555   WASP-192 b   WASP-192          Transit        G0 V  1620.0      2.300
# 561       XO-7 b       XO-7          Transit        G0 V  1743.0      0.709
# 566  eps Ind A b  eps Ind A  Radial Velocity        K5 V   275.0      6.310

# %%
df_small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67 entries, 2 to 566
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_name          67 non-null     object
#  1   hostname         67 non-null     object
#  2   discoverymethod  67 non-null     object
#  3   st_spectype      67 non-null     object
#  4   pl_eqt           67 non-null     float64
#  5   pl_bmassj        67 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 3.7+ KB

# %%
df_small['discoverymethod'].value_counts()
# Out:
# discoverymethod
# Transit            52
# Radial Velocity    13
# Imaging             2
# Name: count, dtype: int64

# %%
# there are three different methods
# 52 transits, 13 radial velocities, 2 imagings
# transits = finds exoplanets by observing a star's light to see if it periodically dims
# radial velocitiy = detecting a star's "wobble" caused by a planet's gravitational pull
# imaging = finds exoplanets through direct method imaging

# %%
import seaborn as sns

# %%
x = df['pl_name']
y = df['pl_eqt']

plt.figure(figsize = (8, 6))
sns.scatterplot(data = df_small, x = 'pl_bmassj', y = 'pl_eqt', hue = 'discoverymethod')
plt.title('Exoplanet Mass vs Equilibrium Temperature')
plt.xlabel('Mass [Jupiter Mass]')
plt.ylabel('Equilibrium Temperature [K]')
plt.legend(title = 'Discover Methods')
plt.show()

# %%
df_small['log_mass'] = np.log(df_small['pl_bmassj'])
df_small['log_temp'] = np.log(df_small['pl_eqt'])

plt.figure(figsize = (8, 6))
sns.scatterplot(data = df_small, x = 'log_mass', y = 'log_temp', hue = 'discoverymethod')
plt.title('Exoplanet Mass vs Equilibrium Temperature')
plt.xlabel('Log Scale of Mass [Jupiter Mass]')
plt.ylabel('Log Scale of Equilibrium Temperature [K]')
plt.legend(title = 'Discover Methods')
plt.show()
# exoplanets found via imaging are more likely to be massive

# %%
df_above5 = df_small[df_small['pl_bmassj'] > 5]
df_above5
# Out:
#          pl_name    hostname  discoverymethod st_spectype  pl_eqt  pl_bmassj  \
# 481   USco1556 b  USco1556 A          Imaging      M3.0 V  2240.0      15.00
# 482   USco1621 b  USco1621 A          Imaging      M2.5 V  2270.0      16.00
# 566  eps Ind A b   eps Ind A  Radial Velocity        K5 V   275.0       6.31
#
#      log_mass  log_temp
# 481  2.708050  7.714231
# 482  2.772589  7.727535
# 566  1.842136  5.616771

# %%
lowest_temp = df_above5['pl_eqt'].idxmin()
print(lowest_temp)
df_above5.loc[566]
# Out:
# 566
# pl_name                eps Ind A b
# hostname                 eps Ind A
# discoverymethod    Radial Velocity
# st_spectype                   K5 V
# pl_eqt                       275.0
# pl_bmassj                     6.31
# log_mass                  1.842136
# log_temp                  5.616771
# Name: 566, dtype: object

# %%
plt.figure(figsize = (8, 6))
sns.scatterplot(data = df_small, x = 'log_mass', y = 'log_temp', hue = 'discoverymethod')

cold_logmass = np.log(df_small.loc[566, 'pl_bmassj'])
cold_logtemp = np.log(df_small.loc[566, 'pl_eqt'])

plt.scatter(cold_logmass, cold_logtemp, c = 'red', s = 200, label = 'Coldest Star')
plt.title('Exoplanet Mass vs Equilibrium Temperature')
plt.xlabel('Log Scale of Mass [Jupiter Mass]')
plt.ylabel('Log Scale of Equilibrium Temperature [K]')
plt.legend(title = 'Discover Methods')
plt.show()

# %%
# 1) A temperate super-Jupiter imaged with JWST in the mid-infrared
# 2) JWST images reveal a giant exoplanet orbiting the older star Eps Ind A.
#    Radial velocity and astronomical acceleration led to the the planet orbiting a star
#    Is probably the only giant planet in its system
# 3) Yes my answer matches
# 4) Yes both the mass the equilibrium temperature's match up
